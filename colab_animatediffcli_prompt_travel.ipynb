# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaleen1234/Auto-GPT/blob/master/colab_animatediffcli_prompt_travel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![ko-fi](https://www.ko-fi.com/img/githubbutton_sm.svg)](https://ko-fi.com/techpractice)

# %% [markdown]
# ### author: tech-practice youtube. Made with ❤️ 2023
# ### youtube tutorial available, [click to subscribe]( https://www.youtube.com/@tech-practice9805?sub_confirmation=1)!
# ### also on Twitter (X): [follow me](https://twitter.com/TechPractice1)
# ### 🎉 click the play button to run each cell. Left panel there is a folder that you can browse for files.

# %%
# !apt-get -qq install aria2
from google.colab import drive
import os, shutil, gc, time
# Out:
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 120875 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link

# %% [markdown]
# If you have any questions running it, feel free to check it out at the tutorial and reach out on [Discord](https://discord.com/invite/SgmBydQ2Mn). If you want to run it locally (needs a Nvidia or AMD GPU), I also video tutorial for them. Including stable diffusion, chatgpt, etc. Subscribe to it today! [Click to subscribe](https://www.youtube.com/@tech-practice9805?sub_confirmation=1)

# %%
# manually create a folder on your google drive. Need to connect it to make results persistent. click "Allow".
# it will ask you for permission.
# create a folder called "AnimateDiffPromptTravel" in it
base_path = "/content/animatediff-cli-prompt-travel"
pwd = %pwd
print(pwd)
if pwd != base_path:
  # !git clone https://github.com/s9roll7/animatediff-cli-prompt-travel
  # %cd {base_path}
  drive.mount("GoogleDrive")
  gd_path = "GoogleDrive/MyDrive/AnimateDiffPromptTravel"
  gd_output_dir = gd_path + "/output"
  os.makedirs(gd_output_dir, exist_ok=True)
  # !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu118
  # !pip install .[dev]
  # !pip install xformers mediapipe
  # !pip install onnxruntime-gpu pandas
# Out:
# /content
# Cloning into 'animatediff-cli-prompt-travel'...
# remote: Enumerating objects: 1233, done.
# remote: Counting objects: 100% (508/508), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 1233 (delta 460), reused 443 (delta 434), pack-reused 725
# Receiving objects: 100% (1233/1233), 2.95 MiB | 17.36 MiB/s, done.
# Resolving deltas: 100% (789/789), done.
# /content/animatediff-cli-prompt-travel
# Mounted at GoogleDrive
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch==2.0.1+cu118 in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: torchvision==0.15.2+cu118 in /usr/local/lib/python3.10/dist-packages (0.15.2+cu118)
# Requirement already satisfied: torchaudio==2.0.2 in /usr/local/lib/python3.10/dist-packages (2.0.2+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1+cu118) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1+cu118) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1+cu118) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1+cu118) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1+cu118) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1+cu118) (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.2+cu118) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.2+cu118) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.2+cu118) (9.4.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1+cu118) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1+cu118) (17.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1+cu118) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.2+cu118) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.2+cu118) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.2+cu118) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.2+cu118) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1+cu118) (1.3.0)
# Processing /content/animatediff-cli-prompt-travel
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting accelerate>=0.20.3 (from animatediff==0.1.dev169+g1840a04)
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 5.5 MB/s eta 0:00:00
# Collecting colorama<0.5.0,>=0.4.3 (from animatediff==0.1.dev169+g1840a04)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: cmake>=3.25.0 in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (3.27.6)
# Collecting diffusers==0.18.2 (from animatediff==0.1.dev169+g1840a04)
#   Downloading diffusers-0.18.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.1 MB/s eta 0:00:00
# Collecting einops>=0.6.1 (from animatediff==0.1.dev169+g1840a04)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: gdown>=4.6.6 in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (4.6.6)
# Collecting ninja>=1.11.0 (from animatediff==0.1.dev169+g1840a04)
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (1.23.5)
# Collecting omegaconf>=2.3.0 (from animatediff==0.1.dev169+g1840a04)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: pillow<10.0.0,>=9.4.0 in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (9.4.0)
# Requirement already satisfied: pydantic<2.0.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (1.10.13)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (13.6.0)
# Collecting safetensors>=0.3.1 (from animatediff==0.1.dev169+g1840a04)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.4 MB/s eta 0:00:00
# Collecting sentencepiece>=0.1.99 (from animatediff==0.1.dev169+g1840a04)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.8 MB/s eta 0:00:00
# Collecting shellingham<2.0.0,>=1.5.0 (from animatediff==0.1.dev169+g1840a04)
#   Downloading shellingham-1.5.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: torch<2.2.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (2.0.1+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (2.0.2+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (0.15.2+cu118)
# Collecting transformers>=4.30.2 (from animatediff==0.1.dev169+g1840a04)
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 106.6 MB/s eta 0:00:00
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (0.9.0)
# Collecting controlnet-aux (from animatediff==0.1.dev169+g1840a04)
#   Downloading controlnet_aux-0.0.7.tar.gz (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.4/202.4 kB 25.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (3.7.1)
# Collecting ffmpeg-python>=0.2.0 (from animatediff==0.1.dev169+g1840a04)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Collecting black>=22.3.0 (from animatediff==0.1.dev169+g1840a04)
#   Downloading black-23.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 86.3 MB/s eta 0:00:00
# Collecting ruff>=0.0.234 (from animatediff==0.1.dev169+g1840a04)
#   Downloading ruff-0.0.292-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 111.1 MB/s eta 0:00:00
# Collecting setuptools-scm>=7.0.0 (from animatediff==0.1.dev169+g1840a04)
#   Using cached setuptools_scm-8.0.4-py3-none-any.whl (42 kB)
# Collecting pre-commit>=3.3.0 (from animatediff==0.1.dev169+g1840a04)
#   Downloading pre_commit-3.4.0-py2.py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from animatediff==0.1.dev169+g1840a04) (7.34.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.18.2->animatediff==0.1.dev169+g1840a04) (3.12.4)
# Collecting huggingface-hub>=0.13.2 (from diffusers==0.18.2->animatediff==0.1.dev169+g1840a04)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 35.1 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.18.2->animatediff==0.1.dev169+g1840a04) (6.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.18.2->animatediff==0.1.dev169+g1840a04) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.18.2->animatediff==0.1.dev169+g1840a04) (2.31.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->animatediff==0.1.dev169+g1840a04) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->animatediff==0.1.dev169+g1840a04) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->animatediff==0.1.dev169+g1840a04) (6.0.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black>=22.3.0->animatediff==0.1.dev169+g1840a04) (8.1.7)
# Collecting mypy-extensions>=0.4.3 (from black>=22.3.0->animatediff==0.1.dev169+g1840a04)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black>=22.3.0->animatediff==0.1.dev169+g1840a04)
#   Downloading pathspec-0.11.2-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black>=22.3.0->animatediff==0.1.dev169+g1840a04) (3.11.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black>=22.3.0->animatediff==0.1.dev169+g1840a04) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black>=22.3.0->animatediff==0.1.dev169+g1840a04) (4.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python>=0.2.0->animatediff==0.1.dev169+g1840a04) (0.18.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown>=4.6.6->animatediff==0.1.dev169+g1840a04) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown>=4.6.6->animatediff==0.1.dev169+g1840a04) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.6.6->animatediff==0.1.dev169+g1840a04) (4.11.2)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.3.0->animatediff==0.1.dev169+g1840a04)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 17.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting cfgv>=2.0.0 (from pre-commit>=3.3.0->animatediff==0.1.dev169+g1840a04)
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Collecting identify>=1.0.0 (from pre-commit>=3.3.0->animatediff==0.1.dev169+g1840a04)
#   Downloading identify-2.5.30-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 14.3 MB/s eta 0:00:00
# Collecting nodeenv>=0.11.1 (from pre-commit>=3.3.0->animatediff==0.1.dev169+g1840a04)
#   Downloading nodeenv-1.8.0-py2.py3-none-any.whl (22 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit>=3.3.0->animatediff==0.1.dev169+g1840a04)
#   Downloading virtualenv-20.24.5-py3-none-any.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 119.5 MB/s eta 0:00:00
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.0.0->animatediff==0.1.dev169+g1840a04) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.0.0->animatediff==0.1.dev169+g1840a04) (2.16.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from setuptools-scm>=7.0.0->animatediff==0.1.dev169+g1840a04) (67.7.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<2.2.0,>=2.0.0->animatediff==0.1.dev169+g1840a04) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<2.2.0,>=2.0.0->animatediff==0.1.dev169+g1840a04) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<2.2.0,>=2.0.0->animatediff==0.1.dev169+g1840a04) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch<2.2.0,>=2.0.0->animatediff==0.1.dev169+g1840a04) (2.0.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch<2.2.0,>=2.0.0->animatediff==0.1.dev169+g1840a04) (17.0.2)
# Collecting tokenizers<0.15,>=0.14 (from transformers>=4.30.2->animatediff==0.1.dev169+g1840a04)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 77.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from controlnet-aux->animatediff==0.1.dev169+g1840a04) (1.11.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from controlnet-aux->animatediff==0.1.dev169+g1840a04) (4.8.0.76)
# Collecting timm (from controlnet-aux->animatediff==0.1.dev169+g1840a04)
#   Downloading timm-0.9.7-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 77.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from controlnet-aux->animatediff==0.1.dev169+g1840a04) (0.19.3)
# Collecting jedi>=0.16 (from ipython->animatediff==0.1.dev169+g1840a04)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.3 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->animatediff==0.1.dev169+g1840a04) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->animatediff==0.1.dev169+g1840a04) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->animatediff==0.1.dev169+g1840a04) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->animatediff==0.1.dev169+g1840a04) (3.0.39)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->animatediff==0.1.dev169+g1840a04) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->animatediff==0.1.dev169+g1840a04) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->animatediff==0.1.dev169+g1840a04) (4.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->animatediff==0.1.dev169+g1840a04) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->animatediff==0.1.dev169+g1840a04) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->animatediff==0.1.dev169+g1840a04) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->animatediff==0.1.dev169+g1840a04) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->animatediff==0.1.dev169+g1840a04) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->animatediff==0.1.dev169+g1840a04) (2.8.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.18.2->animatediff==0.1.dev169+g1840a04) (2023.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->animatediff==0.1.dev169+g1840a04) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->animatediff==0.1.dev169+g1840a04) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->animatediff==0.1.dev169+g1840a04) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->animatediff==0.1.dev169+g1840a04) (0.2.8)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit>=3.3.0->animatediff==0.1.dev169+g1840a04)
#   Downloading distlib-0.3.7-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 31.0 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.6.6->animatediff==0.1.dev169+g1840a04) (2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.18.2->animatediff==0.1.dev169+g1840a04) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<2.2.0,>=2.0.0->animatediff==0.1.dev169+g1840a04) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.18.2->animatediff==0.1.dev169+g1840a04) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.18.2->animatediff==0.1.dev169+g1840a04) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.18.2->animatediff==0.1.dev169+g1840a04) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.18.2->animatediff==0.1.dev169+g1840a04) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.18.2->animatediff==0.1.dev169+g1840a04) (1.7.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->controlnet-aux->animatediff==0.1.dev169+g1840a04) (2.31.5)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->controlnet-aux->animatediff==0.1.dev169+g1840a04) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->controlnet-aux->animatediff==0.1.dev169+g1840a04) (1.4.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<2.2.0,>=2.0.0->animatediff==0.1.dev169+g1840a04) (1.3.0)
# Building wheels for collected packages: antlr4-python3-runtime, animatediff, controlnet-aux
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=7b4c988ae6e8c9ce4fc473917eb12324aec72dee4f659544f7e24871f8eb7f63
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for animatediff (pyproject.toml) ... done
#   Created wheel for animatediff: filename=animatediff-0.1.dev169+g1840a04-py3-none-any.whl size=173559 sha256=c51776b7963efc5f5bf65a96ba8a82e7dec23f321f42b03bb04b0115c05c8ebd
#   Stored in directory: /root/.cache/pip/wheels/68/b1/e0/fc152941e76beb73ab1d505eac509e70e0db4c3f1f080e8744
#   Building wheel for controlnet-aux (setup.py) ... done
#   Created wheel for controlnet-aux: filename=controlnet_aux-0.0.7-py3-none-any.whl size=274341 sha256=3fd657dd3f7c89235e0ac06665cbb6682762eaa6d7df46f3809de6e993468dbb
#   Stored in directory: /root/.cache/pip/wheels/1e/3e/93/6678b4c0bc2ec31d53409b25d4189cbb08bae843e8b2b78e52
# Successfully built antlr4-python3-runtime animatediff controlnet-aux
# Installing collected packages: sentencepiece, ninja, distlib, antlr4-python3-runtime, virtualenv, shellingham, setuptools-scm, safetensors, ruff, pathspec, omegaconf, nodeenv, mypy-extensions, jedi, identify, ffmpeg-python, einops, colorama, cfgv, pre-commit, huggingface-hub, black, tokenizers, diffusers, transformers, timm, controlnet-aux, accelerate, animatediff
# Successfully installed accelerate-0.23.0 animatediff-0.1.dev169+g1840a04 antlr4-python3-runtime-4.9.3 black-23.9.1 cfgv-3.4.0 colorama-0.4.6 controlnet-aux-0.0.7 diffusers-0.18.2 distlib-0.3.7 einops-0.7.0 ffmpeg-python-0.2.0 huggingface-hub-0.17.3 identify-2.5.30 jedi-0.19.1 mypy-extensions-1.0.0 ninja-1.11.1 nodeenv-1.8.0 omegaconf-2.3.0 pathspec-0.11.2 pre-commit-3.4.0 ruff-0.0.292 safetensors-0.4.0 sentencepiece-0.1.99 setuptools-scm-8.0.4 shellingham-1.5.3 timm-0.9.7 tokenizers-0.14.1 transformers-4.34.0 virtualenv-20.24.5
# Collecting xformers
#   Downloading xformers-0.0.22-cp310-cp310-manylinux2014_x86_64.whl (211.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.6/211.6 MB 6.2 MB/s eta 0:00:00
# Collecting mediapipe
#   Downloading mediapipe-0.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.5/33.5 MB 47.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xformers) (1.23.5)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (from xformers) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->xformers) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->xformers) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->xformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->xformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->xformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->xformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->xformers) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->xformers) (17.0.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.8.0.76)
# Requirement already satisfied: protobuf<4,>=3.11 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.20.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->xformers) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->xformers) (1.3.0)
# Installing collected packages: sounddevice, mediapipe, xformers
# Successfully installed mediapipe-0.10.5 sounddevice-0.4.6 xformers-0.0.22
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (153.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 MB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Collecting coloredlogs (from onnxruntime-gpu)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu) (23.5.26)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu) (23.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu) (1.12)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime-gpu) (1.3.0)
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime-gpu
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-gpu-1.16.0

# %%
# AnimateDiff MotionModule download
data_dir = "data"
motion_module = "mm_sd_v15_v2"
motion_module_path = f"models/motion-module/{motion_module}.ckpt"
motion_module_file_path = os.path.join(data_dir, motion_module_path)
if not os.path.exists(motion_module_file_path):
  url = f"https://huggingface.co/guoyww/animatediff/resolve/main/{motion_module}.ckpt"
  # !aria2c {url} -o {motion_module_file_path}
# Out:
# 10/06 17:26:43 [NOTICE] Downloading 1 item(s)
#
# 10/06 17:26:43 [NOTICE] CUID#7 - Redirecting to https://cdn-lfs.huggingface.co/repos/80/a9/80a9efd8e3732d097f2777edd953760ce288e2370fb8a8bb4803c0f8f29dca40/69ed0f5fef82b110aca51bcab73b21104242bc65d6ab4b8b2a2a94d31cad1bf0?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27mm_sd_v15_v2.ckpt%3B+filename%3D%22mm_sd_v15_v2.ckpt%22%3B&Expires=1696867138&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=Xb-ZEOymRocHfxOPrzfVXUdaK7m0l9hBlMq6%7EhODCJq5hYowjweONHYg76AN1Cl4xHtNfnKT1a-cyWpYPzuXkHtPpz4WiuIOacBVbhXC2IT9-gqPNbkGX2YA3u4CtW%7E1pYSFvIvbjx1To8Riz%7E0R8xa1X9MX5sP4I22YHeRfhN5aqrUW1KBeN3ADlmKIRBVtyWIIdpC%7EXy0fSkVIoung3GHHSwnTkZeD9glFjt2qgJxMQx2N%7EBciF534EDPFlLtEY0NIUEzUiLn-%7Ez4hQ9MLR%7Ef%7EPofsgi2-ueHWFDEVxAKY5NzVcYc-6aX8r3F92MZSKVNPPBxj5l1t40Ryhx8y%7EQ__&Key-Pair-Id=KVTP0A1DKRTAX
#
# 10/06 17:26:56 [NOTICE] Download complete: /content/animatediff-cli-prompt-travel/data/models/motion-module/mm_sd_v15_v2.ckpt
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 89022b|OK  |   142MiB/s|/content/animatediff-cli-prompt-travel/data/models/motion-module/mm_sd_v15_v2.ckpt
#
# Status Legend:
# (OK):download completed.

# %%
# SD model download  SD 1.5
# feel free to experiment other models
model_url = "https://civitai.com/api/download/models/102222"
model_name = "xxmix9realistic_v40"
model_path = f"models/sd/{model_name}.safetensors"
model_file_path = os.path.join(data_dir, model_path)
if not os.path.exists(model_file_path):
  # !aria2c {model_url} -o {model_file_path}
# Out:
# 10/06 17:27:44 [NOTICE] Downloading 1 item(s)
#
# 10/06 17:27:46 [NOTICE] CUID#7 - Redirecting to https://civitai-delivery-worker-prod-2023-10-01.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/438091/model/xxmixBiracial34fp16.477s.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22xxmix9realistic_v40.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=2fea663d76bd24a496545da373d610fc/20231006/us-east-1/s3/aws4_request&X-Amz-Date=20231006T172746Z&X-Amz-SignedHeaders=host&X-Amz-Signature=f5fb244e6ba113e4b3d02b051e22028aad3e487b9c23b301dd5d048b4b7f20b1
#
# 10/06 17:28:35 [NOTICE] CUID#7 - Redirecting to https://civitai-delivery-worker-prod-2023-10-01.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/438091/model/xxmixBiracial34fp16.477s.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22xxmix9realistic_v40.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=2fea663d76bd24a496545da373d610fc/20231006/us-east-1/s3/aws4_request&X-Amz-Date=20231006T172835Z&X-Amz-SignedHeaders=host&X-Amz-Signature=2cf4959664a5b8c05f52a2ca791eb97523e8ddc50751159a6ab386dfcd7ccc03
#  *** Download Progress Summary as of Fri Oct  6 17:28:45 2023 ***
# =
# [#d86bb5 1.6GiB/2.2GiB(74%) CN:1 DL:62MiB ETA:9s]
# FILE: /content/animatediff-cli-prompt-travel/data/models/sd/xxmix9realistic_v40.safetensors
# -
#
#
# 10/06 17:28:56 [NOTICE] Download complete: /content/animatediff-cli-prompt-travel/data/models/sd/xxmix9realistic_v40.safetensors
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d86bb5|OK  |    33MiB/s|/content/animatediff-cli-prompt-travel/data/models/sd/xxmix9realistic_v40.safetensors
#
# Status Legend:
# (OK):download completed.

# %%
# test sample config file ### to make updates to the config file (open it and modify. See the youtube video for details!)
# template in: animatediff-cli-prompt-travel/config/prompts/prompt_travel.json
config_sample_txt = """
{
  "name": "Tech-practice-youtube",
  "path": "models/sd/xxmix9realistic_v40.safetensors",
  "motion_module": "models/motion-module/mm_sd_v15_v2.ckpt",
  "compile": false,
  "seed": [
    -1
  ],
  "scheduler": "k_dpmpp_sde",
  "steps": 20,
  "guidance_scale": 10,
  "clip_skip": 2,
  "head_prompt": "1girl, wizard, circlet, earrings, jewelry, purple hair,",
  "prompt_map": {
        "0": "(standing,full_body),blue_sky, town",
        "8": "(sitting,full_body),rain, town",
        "16": "(standing,full_body),blue_sky, woods",
        "24": "(upper_body), beach",
        "32": "(upper_body, smile)",
        "40": "(upper_body, angry)",
        "48": "(upper_body, smile, from_above)",
        "56": "(upper_body, angry, from_side)",
        "64": "(upper_body, smile, from_below)",
        "72": "(upper_body, angry, from_behind, looking at viewer)",
        "80": "face,looking at viewer",
        "88": "face,looking at viewer, closed_eyes",
        "96": "face,looking at viewer, open eyes, open_mouth",
        "104": "face,looking at viewer, closed_eyes, closed_mouth",
        "112": "face,looking at viewer, open eyes,eyes, open_mouth, tongue, smile, laughing",
        "120": "face,looking at viewer, eating, bowl,chopsticks,holding,food"
    },
  "tail_prompt": "clothed, awesome and detailed background",
  "n_prompt": [
    "(worst quality, low quality:1.4),nudity,simple background"
  ],
  "lora_map": {
  },
  "motion_lora_map": {
  },
  "ip_adapter_map": {
      "enable": true,
      "input_image_dir": "ip_adapter_image/test",
      "save_input_image": true,
      "resized_to_square": false,
      "scale": 0.5,
      "is_plus_face": true,
      "is_plus": true
  },
  "controlnet_map": {
    "input_image_dir" : "controlnet_image/test",
    "max_samples_on_vram": 200,
    "max_models_on_vram" : 3,
    "save_detectmap": true,
    "preprocess_on_gpu": true,
    "is_loop": true,

    "controlnet_tile":{
      "enable": true,
      "use_preprocessor":true,
      "preprocessor":{
        "type" : "none",
        "param":{
        }
      },
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_ip2p":{
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_lineart_anime":{
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_openpose":{
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_softedge":{
      "enable": true,
      "use_preprocessor":true,
      "preprocessor":{
        "type" : "softedge_pidsafe",
        "param":{
        }
      },
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_shuffle": {
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_depth": {
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_canny": {
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_inpaint": {
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_lineart": {
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_mlsd": {
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_normalbae": {
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_scribble": {
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_seg": {
      "enable": true,
      "use_preprocessor":true,
      "guess_mode":false,
      "controlnet_conditioning_scale": 1.0,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0,
      "control_scale_list":[0.5,0.4,0.3,0.2,0.1]
    },
    "controlnet_ref": {
        "enable": false,
        "ref_image": "ref_image/ref_sample.png",
        "attention_auto_machine_weight": 0.3,
        "gn_auto_machine_weight": 0.3,
        "style_fidelity": 0.5,
        "reference_attn": true,
        "reference_adain": false,
        "scale_pattern":[1.0]
    }
  },
  "upscale_config": {
    "scheduler": "k_dpmpp_sde",
    "steps": 20,
    "strength": 0.5,
    "guidance_scale": 10,
    "controlnet_tile": {
      "enable": true,
      "controlnet_conditioning_scale": 1.0,
      "guess_mode": false,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0
    },
    "controlnet_line_anime": {
      "enable": false,
      "controlnet_conditioning_scale": 1.0,
      "guess_mode": false,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0
    },
    "controlnet_ip2p": {
      "enable": false,
      "controlnet_conditioning_scale": 0.5,
      "guess_mode": false,
      "control_guidance_start": 0.0,
      "control_guidance_end": 1.0
    },
    "controlnet_ref": {
      "enable": false,
      "use_frame_as_ref_image": false,
      "use_1st_frame_as_ref_image": false,
      "ref_image": "ref_image/path_to_your_ref_img.jpg",
      "attention_auto_machine_weight": 1.0,
      "gn_auto_machine_weight": 1.0,
      "style_fidelity": 0.25,
      "reference_attn": true,
      "reference_adain": false
    }
  },
  "output":{
    "format" : "gif",
    "fps" : 8,
    "encode_param":{
      "crf": 10
    }
  }
}
"""
config_file_path = f"config/prompts/test001.json"
with open(config_file_path, "w") as file:
    file.write(config_sample_txt)

# %%
# take about 4-5 minutes. -W is width -H height. -L length.  can use -W 512 -H 768
# !animatediff generate -c config/prompts/test001.json -W 256 -H 384 -L 128 -C 16
# Out:
# 2023-10-06 16:52:22.153789: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using generation config: config/prompts/test001.json
# is_v2=True
# Using base model: runwayml/stable-diffusion-v1-5
# Downloading base model from runwayml/stable-diffusion-v1-5...
# Downloading (…)ain/model_index.json: 100% 541/541 [00:00<00:00, 3.68MB/s]
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# Downloading (…)cheduler_config.json: 100% 308/308 [00:00<00:00, 1.87MB/s]
#
# Downloading (…)tokenizer/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
# Downloading (…)_encoder/config.json: 100% 617/617 [00:00<00:00, 5.04MB/s]
#
#
# Downloading (…)rocessor_config.json: 100% 342/342 [00:00<00:00, 1.38MB/s]
# Fetching 15 files:   7% 1/15 [00:01<00:15,  1.12s/it]
#
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 2.71MB/s]
#
#
# Downloading (…)_checker/config.json: 100% 4.72k/4.72k [00:00<00:00, 27.9MB/s]
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 9.15MB/s]
#
# Downloading (…)okenizer_config.json: 100% 806/806 [00:00<00:00, 6.72MB/s]
#
# Downloading (…)5b9/unet/config.json: 100% 743/743 [00:00<00:00, 6.04MB/s]
#
# Downloading (…)tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# Downloading (…)b5b9/vae/config.json: 100% 547/547 [00:00<00:00, 3.58MB/s]
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 14.9MB/s]
#
# Downloading model.safetensors:   0% 0.00/1.22G [00:00<?, ?B/s]
#
# Downloading model.safetensors:   0% 0.00/492M [00:00<?, ?B/s]
#
#
# Downloading (…)ch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0% 0.00/3.44G [00:00<?, ?B/s]
# Downloading model.safetensors:   1% 10.5M/1.22G [00:00<00:15, 79.8MB/s]
#
# Downloading model.safetensors:   2% 10.5M/492M [00:00<00:05, 82.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 10.5M/335M [00:00<00:05, 61.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0% 10.5M/3.44G [00:00<00:56, 60.2MB/s]
#
# Downloading model.safetensors:   4% 21.0M/492M [00:00<00:05, 87.3MB/s]
# Downloading model.safetensors:   3% 31.5M/1.22G [00:00<00:11, 102MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 21.0M/335M [00:00<00:04, 74.3MB/s]
#
# Downloading model.safetensors:   6% 31.5M/492M [00:00<00:04, 92.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   1% 21.0M/3.44G [00:00<00:44, 77.5MB/s]
# Downloading model.safetensors:   3% 41.9M/1.22G [00:00<00:11, 102MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   1% 31.5M/3.44G [00:00<00:42, 80.0MB/s]
#
# Downloading model.safetensors:   9% 41.9M/492M [00:00<00:05, 84.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 31.5M/335M [00:00<00:04, 68.1MB/s]
# Downloading model.safetensors:   4% 52.4M/1.22G [00:00<00:14, 83.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   1% 41.9M/3.44G [00:00<00:44, 75.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 41.9M/335M [00:00<00:04, 69.8MB/s]
#
# Downloading model.safetensors:  11% 52.4M/492M [00:00<00:05, 78.4MB/s]
# Downloading model.safetensors:   5% 62.9M/1.22G [00:00<00:14, 79.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   2% 52.4M/3.44G [00:00<00:45, 73.9MB/s]
#
# Downloading model.safetensors:  13% 62.9M/492M [00:00<00:05, 75.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 52.4M/335M [00:00<00:03, 70.8MB/s]
# Downloading model.safetensors:   6% 73.4M/1.22G [00:00<00:16, 70.4MB/s]
#
# Downloading model.safetensors:  15% 73.4M/492M [00:00<00:05, 71.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   2% 62.9M/3.44G [00:00<00:49, 67.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 62.9M/335M [00:00<00:04, 67.7MB/s]
# Downloading model.safetensors:   7% 83.9M/1.22G [00:01<00:15, 75.1MB/s]
#
# Downloading model.safetensors:  17% 83.9M/492M [00:01<00:05, 74.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   2% 73.4M/3.44G [00:01<00:47, 70.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 73.4M/335M [00:01<00:03, 68.3MB/s]
# Downloading model.safetensors:   8% 94.4M/1.22G [00:01<00:16, 70.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   2% 83.9M/3.44G [00:01<00:47, 70.8MB/s]
#
# Downloading model.safetensors:  19% 94.4M/492M [00:01<00:05, 70.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 83.9M/335M [00:01<00:03, 69.4MB/s]
# Downloading model.safetensors:   9% 105M/1.22G [00:01<00:14, 74.6MB/s]
#
# Downloading model.safetensors:  21% 105M/492M [00:01<00:05, 75.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3% 94.4M/3.44G [00:01<00:45, 73.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  28% 94.4M/335M [00:01<00:03, 72.0MB/s]
#
# Downloading model.safetensors:  23% 115M/492M [00:01<00:04, 81.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   3% 105M/3.44G [00:01<00:41, 79.7MB/s]
# Downloading model.safetensors:  10% 126M/1.22G [00:01<00:12, 88.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  31% 105M/335M [00:01<00:02, 79.3MB/s]
#
# Downloading model.safetensors:  26% 126M/492M [00:01<00:04, 85.4MB/s]
# Downloading model.safetensors:  11% 136M/1.22G [00:01<00:11, 91.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  34% 115M/335M [00:01<00:02, 81.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4% 126M/3.44G [00:01<00:35, 94.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  38% 126M/335M [00:01<00:02, 85.8MB/s]
# Downloading model.safetensors:  12% 147M/1.22G [00:01<00:12, 87.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4% 136M/3.44G [00:01<00:35, 94.0MB/s]
#
# Downloading model.safetensors:  30% 147M/492M [00:01<00:03, 92.2MB/s]
# Downloading model.safetensors:  13% 157M/1.22G [00:01<00:11, 88.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  41% 136M/335M [00:01<00:02, 83.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   4% 147M/3.44G [00:01<00:38, 85.5MB/s]
# Downloading model.safetensors:  14% 168M/1.22G [00:02<00:12, 80.8MB/s]
#
# Downloading model.safetensors:  32% 157M/492M [00:02<00:04, 73.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5% 157M/3.44G [00:02<00:40, 80.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  44% 147M/335M [00:02<00:02, 67.1MB/s]
#
# Downloading model.safetensors:  34% 168M/492M [00:02<00:04, 78.2MB/s]
# Downloading model.safetensors:  15% 178M/1.22G [00:02<00:14, 72.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5% 168M/3.44G [00:02<00:42, 77.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  47% 157M/335M [00:02<00:02, 64.2MB/s]
#
# Downloading model.safetensors:  36% 178M/492M [00:02<00:04, 74.1MB/s]
# Downloading model.safetensors:  16% 189M/1.22G [00:02<00:14, 68.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5% 178M/3.44G [00:02<00:43, 75.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  50% 168M/335M [00:02<00:02, 63.3MB/s]
#
# Downloading model.safetensors:  38% 189M/492M [00:02<00:04, 70.0MB/s]
# Downloading model.safetensors:  16% 199M/1.22G [00:02<00:14, 70.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   5% 189M/3.44G [00:02<00:43, 73.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  53% 178M/335M [00:02<00:02, 61.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6% 199M/3.44G [00:02<00:45, 71.6MB/s]
#
# Downloading model.safetensors:  40% 199M/492M [00:02<00:05, 55.7MB/s]
# Downloading model.safetensors:  17% 210M/1.22G [00:02<00:17, 56.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  56% 189M/335M [00:02<00:02, 54.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6% 210M/3.44G [00:02<00:51, 62.6MB/s]
#
# Downloading model.safetensors:  43% 210M/492M [00:02<00:04, 57.3MB/s]
# Downloading model.safetensors:  18% 220M/1.22G [00:03<00:18, 54.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  60% 199M/335M [00:02<00:02, 60.2MB/s]
#
# Downloading model.safetensors:  45% 220M/492M [00:03<00:04, 65.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6% 220M/3.44G [00:02<00:49, 65.0MB/s]
#
# Downloading model.safetensors:  47% 231M/492M [00:03<00:04, 57.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  63% 210M/335M [00:03<00:02, 51.2MB/s]
#
# Downloading model.safetensors:  49% 241M/492M [00:03<00:04, 62.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7% 231M/3.44G [00:03<01:07, 47.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  69% 231M/335M [00:03<00:01, 68.7MB/s]
# Downloading model.safetensors:  19% 231M/1.22G [00:03<00:26, 36.6MB/s]
#
# Downloading model.safetensors:  51% 252M/492M [00:03<00:03, 67.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7% 241M/3.44G [00:03<01:00, 53.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  72% 241M/335M [00:03<00:01, 69.9MB/s]
# Downloading model.safetensors:  20% 241M/1.22G [00:03<00:22, 43.0MB/s]
#
# Downloading model.safetensors:  53% 262M/492M [00:03<00:03, 63.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   7% 252M/3.44G [00:03<00:57, 55.4MB/s]
# Downloading model.safetensors:  21% 252M/1.22G [00:03<00:19, 49.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  75% 252M/335M [00:03<00:01, 65.0MB/s]
#
# Downloading model.safetensors:  55% 273M/492M [00:03<00:03, 67.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8% 262M/3.44G [00:03<00:54, 58.7MB/s]
# Downloading model.safetensors:  22% 262M/1.22G [00:03<00:16, 58.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  78% 262M/335M [00:03<00:01, 71.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8% 273M/3.44G [00:03<00:47, 66.8MB/s]
# Downloading model.safetensors:  22% 273M/1.22G [00:04<00:14, 64.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  81% 273M/335M [00:04<00:00, 70.7MB/s]
#
# Downloading model.safetensors:  60% 294M/492M [00:04<00:02, 76.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   8% 283M/3.44G [00:04<00:42, 74.6MB/s]
# Downloading model.safetensors:  23% 283M/1.22G [00:04<00:13, 71.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 283M/335M [00:04<00:00, 76.9MB/s]
#
# Downloading model.safetensors:  62% 304M/492M [00:04<00:02, 69.5MB/s]
# Downloading model.safetensors:  24% 294M/1.22G [00:04<00:13, 69.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9% 294M/3.44G [00:04<00:48, 65.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 294M/335M [00:04<00:00, 74.1MB/s]
#
# Downloading model.safetensors:  64% 315M/492M [00:04<00:02, 74.2MB/s]
# Downloading model.safetensors:  25% 304M/1.22G [00:04<00:13, 67.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9% 304M/3.44G [00:04<00:47, 66.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 304M/335M [00:04<00:00, 68.8MB/s]
#
# Downloading model.safetensors:  66% 325M/492M [00:04<00:02, 73.4MB/s]
# Downloading model.safetensors:  26% 315M/1.22G [00:04<00:13, 66.5MB/s]
#
# Downloading model.safetensors:  68% 336M/492M [00:04<00:02, 73.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 315M/335M [00:04<00:00, 65.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9% 315M/3.44G [00:04<00:56, 55.5MB/s]
# Downloading model.safetensors:  27% 325M/1.22G [00:04<00:12, 68.9MB/s]
#
# Downloading model.safetensors:  70% 346M/492M [00:04<00:01, 74.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 325M/335M [00:04<00:00, 63.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   9% 325M/3.44G [00:04<00:54, 56.9MB/s]
# Downloading model.safetensors:  28% 336M/1.22G [00:04<00:13, 66.3MB/s]
#
# Downloading model.safetensors:  72% 357M/492M [00:04<00:01, 76.4MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:04<00:00, 61.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  10% 336M/3.44G [00:04<00:54, 57.4MB/s]
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:05<00:00, 66.0MB/s]
#
#
# Downloading model.safetensors:  75% 367M/492M [00:05<00:01, 66.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  10% 346M/3.44G [00:05<00:50, 61.2MB/s]
# Downloading model.safetensors:  29% 357M/1.22G [00:05<00:13, 65.6MB/s]
#
# Downloading model.safetensors:  77% 377M/492M [00:05<00:01, 70.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  10% 357M/3.44G [00:05<00:45, 68.2MB/s]
# Downloading model.safetensors:  30% 367M/1.22G [00:05<00:12, 68.3MB/s]
#
# Downloading model.safetensors:  79% 388M/492M [00:05<00:01, 73.9MB/s]
# Downloading model.safetensors:  31% 377M/1.22G [00:05<00:11, 70.9MB/s]
#
# Downloading model.safetensors:  81% 398M/492M [00:05<00:01, 74.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  11% 377M/3.44G [00:05<00:40, 74.7MB/s]
#
# Downloading model.safetensors:  83% 409M/492M [00:05<00:01, 75.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  11% 388M/3.44G [00:05<00:39, 76.9MB/s]
# Downloading model.safetensors:  33% 398M/1.22G [00:05<00:09, 82.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12% 398M/3.44G [00:05<00:39, 77.4MB/s]
# Downloading model.safetensors:  34% 409M/1.22G [00:05<00:09, 82.1MB/s]
#
# Downloading model.safetensors:  87% 430M/492M [00:05<00:00, 83.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12% 409M/3.44G [00:05<00:37, 79.9MB/s]
# Downloading model.safetensors:  34% 419M/1.22G [00:05<00:09, 82.7MB/s]
#
# Downloading model.safetensors:  89% 440M/492M [00:06<00:00, 78.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  12% 419M/3.44G [00:06<00:38, 78.0MB/s]
# Downloading model.safetensors:  35% 430M/1.22G [00:06<00:10, 76.0MB/s]
#
# Downloading model.safetensors:  92% 451M/492M [00:06<00:00, 75.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13% 430M/3.44G [00:06<00:40, 73.4MB/s]
# Downloading model.safetensors:  36% 440M/1.22G [00:06<00:09, 79.5MB/s]
#
# Downloading model.safetensors:  94% 461M/492M [00:06<00:00, 71.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13% 440M/3.44G [00:06<00:43, 68.9MB/s]
# Downloading model.safetensors:  37% 451M/1.22G [00:06<00:10, 72.7MB/s]
#
# Downloading model.safetensors:  96% 472M/492M [00:06<00:00, 78.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13% 451M/3.44G [00:06<00:40, 74.0MB/s]
# Downloading model.safetensors:  38% 461M/1.22G [00:06<00:10, 74.6MB/s]
#
# Downloading model.safetensors:  98% 482M/492M [00:06<00:00, 80.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13% 461M/3.44G [00:06<00:38, 76.8MB/s]
# Downloading model.safetensors:  39% 472M/1.22G [00:06<00:09, 78.1MB/s]
#
# Downloading model.safetensors: 100% 492M/492M [00:06<00:00, 78.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  14% 472M/3.44G [00:06<00:36, 80.9MB/s]
# Downloading model.safetensors: 100% 492M/492M [00:06<00:00, 72.4MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:  14% 482M/3.44G [00:06<00:39, 74.0MB/s]
# Downloading model.safetensors:  41% 493M/1.22G [00:06<00:09, 75.4MB/s]
# Downloading model.safetensors:  41% 503M/1.22G [00:07<00:10, 65.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  14% 493M/3.44G [00:07<00:47, 62.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  15% 514M/3.44G [00:07<00:33, 86.4MB/s]
# Downloading model.safetensors:  43% 524M/1.22G [00:07<00:07, 87.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  16% 535M/3.44G [00:07<00:27, 104MB/s]
# Downloading model.safetensors:  45% 545M/1.22G [00:07<00:06, 102MB/s]
# Downloading model.safetensors:  46% 556M/1.22G [00:07<00:06, 97.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  16% 556M/3.44G [00:07<00:27, 105MB/s]
# Downloading model.safetensors:  47% 566M/1.22G [00:07<00:06, 97.5MB/s]
# Downloading model.safetensors:  47% 577M/1.22G [00:07<00:06, 96.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  17% 577M/3.44G [00:07<00:27, 103MB/s]
# Downloading model.safetensors:  49% 598M/1.22G [00:08<00:06, 101MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  17% 598M/3.44G [00:07<00:27, 102MB/s]
# Downloading model.safetensors:  50% 608M/1.22G [00:08<00:06, 98.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  18% 619M/3.44G [00:08<00:27, 101MB/s]
# Downloading model.safetensors:  52% 629M/1.22G [00:08<00:06, 96.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  18% 629M/3.44G [00:08<00:28, 97.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  19% 640M/3.44G [00:08<00:28, 98.4MB/s]
# Downloading model.safetensors:  53% 650M/1.22G [00:08<00:05, 98.5MB/s]
# Downloading model.safetensors:  54% 661M/1.22G [00:09<00:10, 53.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  19% 661M/3.44G [00:12<03:35, 12.9MB/s]
# Downloading model.safetensors:  55% 671M/1.22G [00:12<00:48, 11.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  20% 671M/3.44G [00:12<02:56, 15.7MB/s]
# Downloading model.safetensors:  56% 682M/1.22G [00:12<00:38, 14.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  20% 682M/3.44G [00:12<02:23, 19.3MB/s]
# Downloading model.safetensors:  57% 692M/1.22G [00:12<00:29, 17.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  20% 692M/3.44G [00:12<01:58, 23.1MB/s]
# Downloading model.safetensors:  58% 703M/1.22G [00:12<00:22, 22.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  21% 713M/3.44G [00:13<01:18, 34.9MB/s]
# Downloading model.safetensors:  60% 724M/1.22G [00:13<00:14, 33.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  21% 724M/3.44G [00:13<01:07, 40.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  22% 744M/3.44G [00:13<00:47, 56.9MB/s]
# Downloading model.safetensors:  61% 744M/1.22G [00:13<00:09, 47.2MB/s]
# Downloading model.safetensors:  62% 755M/1.22G [00:13<00:10, 45.0MB/s]
# Downloading model.safetensors:  63% 765M/1.22G [00:13<00:08, 51.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  22% 765M/3.44G [00:13<00:47, 56.1MB/s]
# Downloading model.safetensors:  64% 776M/1.22G [00:13<00:07, 59.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  23% 776M/3.44G [00:13<00:43, 61.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  23% 797M/3.44G [00:13<00:35, 75.0MB/s]
# Downloading model.safetensors:  66% 797M/1.22G [00:14<00:05, 73.2MB/s]
# Downloading model.safetensors:  66% 807M/1.22G [00:14<00:05, 77.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  24% 818M/3.44G [00:14<00:29, 89.3MB/s]
# Downloading model.safetensors:  68% 828M/1.22G [00:14<00:04, 93.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  24% 839M/3.44G [00:14<00:27, 96.1MB/s]
# Downloading model.safetensors:  70% 849M/1.22G [00:14<00:03, 102MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  25% 860M/3.44G [00:14<00:24, 103MB/s]
# Downloading model.safetensors:  72% 870M/1.22G [00:14<00:03, 109MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  26% 881M/3.44G [00:14<00:22, 114MB/s]
# Downloading model.safetensors:  73% 891M/1.22G [00:14<00:02, 114MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  26% 902M/3.44G [00:14<00:22, 115MB/s]
# Downloading model.safetensors:  75% 912M/1.22G [00:14<00:02, 121MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  27% 923M/3.44G [00:14<00:21, 118MB/s]
# Downloading model.safetensors:  77% 933M/1.22G [00:15<00:02, 123MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  27% 944M/3.44G [00:15<00:20, 121MB/s]
# Downloading model.safetensors:  78% 954M/1.22G [00:15<00:02, 128MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  28% 965M/3.44G [00:15<00:21, 116MB/s]
# Downloading model.safetensors:  80% 975M/1.22G [00:15<00:01, 124MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  29% 986M/3.44G [00:15<00:21, 114MB/s]
# Downloading model.safetensors:  82% 996M/1.22G [00:15<00:01, 122MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  29% 1.01G/3.44G [00:15<00:21, 113MB/s]
# Downloading model.safetensors:  84% 1.02G/1.22G [00:15<00:01, 125MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  30% 1.03G/3.44G [00:15<00:20, 117MB/s]
# Downloading model.safetensors:  85% 1.04G/1.22G [00:15<00:01, 119MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  30% 1.05G/3.44G [00:16<00:19, 120MB/s]
# Downloading model.safetensors:  87% 1.06G/1.22G [00:16<00:01, 126MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  31% 1.07G/3.44G [00:16<00:20, 117MB/s]
# Downloading model.safetensors:  89% 1.08G/1.22G [00:16<00:01, 122MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  32% 1.09G/3.44G [00:16<00:19, 120MB/s]
# Downloading model.safetensors:  91% 1.10G/1.22G [00:16<00:00, 123MB/s]
# Downloading model.safetensors:  92% 1.12G/1.22G [00:16<00:00, 125MB/s]
# Downloading model.safetensors:  94% 1.14G/1.22G [00:16<00:00, 138MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  32% 1.11G/3.44G [00:16<00:26, 87.9MB/s]
# Downloading model.safetensors:  96% 1.16G/1.22G [00:16<00:00, 141MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  33% 1.13G/3.44G [00:16<00:23, 99.4MB/s]
# Downloading model.safetensors:  97% 1.18G/1.22G [00:17<00:00, 139MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  34% 1.15G/3.44G [00:17<00:21, 106MB/s]
# Downloading model.safetensors:  99% 1.21G/1.22G [00:17<00:00, 121MB/s]
#
#
#
# Downloading model.safetensors: 100% 1.22G/1.22G [00:17<00:00, 69.8MB/s]
# Fetching 15 files:  27% 4/15 [00:19<00:55,  5.07s/it]
#
#
#
# Downloading (…)ch_model.safetensors:  35% 1.20G/3.44G [00:17<00:19, 113MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  35% 1.22G/3.44G [00:17<00:17, 128MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  36% 1.24G/3.44G [00:17<00:15, 139MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  37% 1.26G/3.44G [00:17<00:14, 150MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  37% 1.28G/3.44G [00:17<00:13, 159MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  38% 1.30G/3.44G [00:18<00:13, 164MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  38% 1.32G/3.44G [00:18<00:13, 158MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  39% 1.34G/3.44G [00:18<00:13, 159MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  40% 1.36G/3.44G [00:18<00:12, 163MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  40% 1.38G/3.44G [00:18<00:12, 165MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  41% 1.41G/3.44G [00:18<00:12, 163MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  41% 1.43G/3.44G [00:18<00:11, 169MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  42% 1.45G/3.44G [00:18<00:11, 177MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  43% 1.47G/3.44G [00:18<00:10, 181MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  43% 1.49G/3.44G [00:19<00:10, 182MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  44% 1.51G/3.44G [00:19<00:10, 180MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  45% 1.53G/3.44G [00:19<00:10, 176MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  45% 1.55G/3.44G [00:19<00:11, 166MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  46% 1.57G/3.44G [00:19<00:11, 165MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  46% 1.59G/3.44G [00:19<00:10, 169MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  47% 1.61G/3.44G [00:19<00:10, 174MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  48% 1.64G/3.44G [00:19<00:10, 177MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  48% 1.66G/3.44G [00:20<00:09, 179MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  49% 1.68G/3.44G [00:20<00:09, 182MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  49% 1.70G/3.44G [00:20<00:09, 182MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  50% 1.72G/3.44G [00:20<00:09, 186MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  51% 1.74G/3.44G [00:20<00:09, 181MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  51% 1.76G/3.44G [00:20<00:09, 182MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  52% 1.78G/3.44G [00:20<00:09, 178MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  52% 1.80G/3.44G [00:20<00:09, 175MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  53% 1.82G/3.44G [00:21<00:09, 176MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  54% 1.85G/3.44G [00:22<00:39, 40.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  54% 1.87G/3.44G [00:22<00:29, 53.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  55% 1.89G/3.44G [00:22<00:22, 67.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  56% 1.91G/3.44G [00:22<00:20, 75.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  56% 1.93G/3.44G [00:22<00:16, 91.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  57% 1.95G/3.44G [00:23<00:13, 108MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  57% 1.97G/3.44G [00:23<00:11, 126MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  58% 1.99G/3.44G [00:23<00:11, 125MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  59% 2.01G/3.44G [00:23<00:10, 135MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  59% 2.03G/3.44G [00:23<00:10, 136MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  60% 2.06G/3.44G [00:23<00:09, 143MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  60% 2.08G/3.44G [00:23<00:08, 155MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  61% 2.10G/3.44G [00:24<00:08, 163MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  62% 2.12G/3.44G [00:24<00:07, 173MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  62% 2.14G/3.44G [00:24<00:07, 180MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  63% 2.17G/3.44G [00:24<00:06, 190MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  64% 2.19G/3.44G [00:24<00:06, 191MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  64% 2.21G/3.44G [00:24<00:06, 183MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  65% 2.23G/3.44G [00:24<00:07, 172MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  66% 2.25G/3.44G [00:24<00:06, 171MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  66% 2.28G/3.44G [00:24<00:06, 170MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  67% 2.30G/3.44G [00:26<00:27, 41.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  67% 2.32G/3.44G [00:27<00:35, 31.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  68% 2.34G/3.44G [00:27<00:26, 41.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  69% 2.36G/3.44G [00:27<00:21, 50.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  69% 2.38G/3.44G [00:27<00:16, 64.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  70% 2.40G/3.44G [00:27<00:12, 81.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  71% 2.43G/3.44G [00:28<00:09, 108MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  71% 2.45G/3.44G [00:28<00:08, 121MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  72% 2.47G/3.44G [00:28<00:07, 132MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  73% 2.50G/3.44G [00:28<00:06, 146MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  73% 2.52G/3.44G [00:28<00:05, 160MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  74% 2.55G/3.44G [00:28<00:05, 176MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  75% 2.57G/3.44G [00:28<00:04, 184MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  76% 2.60G/3.44G [00:28<00:04, 194MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  76% 2.62G/3.44G [00:29<00:04, 197MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  77% 2.65G/3.44G [00:29<00:03, 204MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  78% 2.67G/3.44G [00:29<00:03, 200MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  78% 2.69G/3.44G [00:29<00:03, 198MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  79% 2.72G/3.44G [00:29<00:03, 198MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  80% 2.74G/3.44G [00:29<00:03, 192MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  80% 2.76G/3.44G [00:29<00:03, 193MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  81% 2.79G/3.44G [00:29<00:03, 200MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  82% 2.82G/3.44G [00:30<00:03, 199MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  83% 2.84G/3.44G [00:30<00:02, 202MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  83% 2.86G/3.44G [00:30<00:02, 203MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  84% 2.88G/3.44G [00:30<00:02, 204MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  85% 2.92G/3.44G [00:30<00:02, 206MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  85% 2.94G/3.44G [00:30<00:02, 205MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  86% 2.96G/3.44G [00:30<00:02, 194MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  87% 2.98G/3.44G [00:30<00:02, 193MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  87% 3.00G/3.44G [00:30<00:02, 188MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  88% 3.02G/3.44G [00:31<00:02, 188MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  88% 3.04G/3.44G [00:31<00:02, 190MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  89% 3.06G/3.44G [00:31<00:02, 184MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  90% 3.08G/3.44G [00:32<00:06, 51.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  90% 3.10G/3.44G [00:32<00:05, 66.0MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  91% 3.12G/3.44G [00:32<00:05, 59.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  91% 3.15G/3.44G [00:33<00:03, 74.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  92% 3.17G/3.44G [00:33<00:03, 88.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  93% 3.19G/3.44G [00:33<00:02, 103MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  93% 3.21G/3.44G [00:33<00:01, 116MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  94% 3.23G/3.44G [00:33<00:01, 129MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  95% 3.25G/3.44G [00:33<00:01, 135MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  95% 3.27G/3.44G [00:33<00:01, 138MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  96% 3.30G/3.44G [00:34<00:00, 159MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  97% 3.32G/3.44G [00:34<00:00, 170MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  97% 3.34G/3.44G [00:34<00:00, 177MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  98% 3.37G/3.44G [00:34<00:00, 182MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  99% 3.39G/3.44G [00:34<00:00, 172MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  99% 3.41G/3.44G [00:34<00:00, 170MB/s]
#
#
#
# Downloading (…)ch_model.safetensors: 100% 3.44G/3.44G [00:34<00:00, 98.8MB/s]
# Fetching 15 files: 100% 15/15 [00:36<00:00,  2.44s/it]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
# Saving pipeline to data/models/huggingface/stable-diffusion-v1-5
# Will save outputs to ./output/2023-10-06T16-54-01-tech-practice-xxmix9realistic_v40
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading dw-ll_ucoco_384.onnx:   0% 0.00/134M [00:00<?, ?B/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading dw-ll_ucoco_384.onnx:   8% 10.5M/134M [00:00<00:04, 26.7MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading dw-ll_ucoco_384.onnx:  16% 21.0M/134M [00:00<00:02, 45.1MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading dw-ll_ucoco_384.onnx:  31% 41.9M/134M [00:00<00:01, 75.0MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading dw-ll_ucoco_384.onnx:  47% 62.9M/134M [00:00<00:00, 97.8MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading dw-ll_ucoco_384.onnx:  62% 83.9M/134M [00:00<00:00, 119MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading dw-ll_ucoco_384.onnx:  78% 105M/134M [00:01<00:00, 124MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading dw-ll_ucoco_384.onnx:  94% 126M/134M [00:01<00:00, 135MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading dw-ll_ucoco_384.onnx: 100% 134M/134M [00:01<00:00, 101MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx:   0% 0.00/217M [00:00<?, ?B/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx:  10% 21.0M/217M [00:00<00:01, 140MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx:  19% 41.9M/217M [00:00<00:01, 155MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx:  29% 62.9M/217M [00:00<00:00, 156MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx:  39% 83.9M/217M [00:00<00:00, 152MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx:  48% 105M/217M [00:00<00:00, 151MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx:  58% 126M/217M [00:00<00:00, 155MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx:  68% 147M/217M [00:00<00:00, 161MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx:  77% 168M/217M [00:01<00:00, 166MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx:  87% 189M/217M [00:01<00:00, 166MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx:  97% 210M/217M [00:01<00:00, 170MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading yolox_l.onnx: 100% 217M/217M [00:01<00:00, 158MB/s]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#                                                                           it/s  2023-10-06 16:54:20.525043847 [W:onnxruntime:, session_state.cc:1162 VerifyEachNodeIsAssignedToAnEp] Some nodes were not assigned to the preferred execution providers which may or may not have an negative impact on performance. e.g. ORT explicitly assigns shape related ops to CPU to improve perf.
# 2023-10-06 16:54:20.525076937 [W:onnxruntime:, session_state.cc:1164 VerifyEachNodeIsAssignedToAnEp] Rerunning with verbose output on a non-minimal build will show node assignments.
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)  33% ━╺━━ 1/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)  33% ━╺━━ 1/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_openpose)  67% ━━╸━ 2/3  [ 0:0… < 0:0… , 4    ]
# Preprocessing images (controlnet_openpose)  67% ━━╸━ 2/3  [ 0:0… < 0:0… , 4    ]
#                                                                           it/s
# Saving Preprocessed images (controlnet_openpose)   0% ━━━ 0/3 [ 0:… < -… , ?   ]
# Saving Preprocessed images (controlnet_openpose)   0% ━━━ 0/3 [ 0:… < -… , ?   ]
#                                                                            it…
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#                                                                           it/s  Loading softedge_pidsafe
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading table5_pidinet.pth:   0% 0.00/2.87M [00:00<?, ?B/s]
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading table5_pidinet.pth: 100% 2.87M/2.87M [00:00<00:00, 13.1MB/s]
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# [A
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Downloading table5_pidinet.pth: 100% 2.87M/2.87M [00:00<00:00, 12.3MB/s]
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
#
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_softedge)   0% ━━━━ 0/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_softedge)  33% ━╺━━ 1/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_softedge)  33% ━╺━━ 1/3  [ 0:0… < -:-… , ?    ]
# Preprocessing images (controlnet_softedge) 100% ━━━━ 3/3  [ 0:0… < 0:0… , 11   ]
#                                                                           it/s
# Saving Preprocessed images (controlnet_softedge)   0% ━━━ 0/3 [ 0:… < -… , ?   ]
# Saving Preprocessed images (controlnet_softedge)   0% ━━━ 0/3 [ 0:… < -… , ?   ]
# Saving Preprocessed images (controlnet_softedge) 100% ━━━ 3/3 [ 0:… < 0… , ?   ]
#                                                                            it…
# Checking motion module...
# Loading tokenizer...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading text encoder...
# Loading VAE...
# Loading UNet...
# Loaded 453.20928M-parameter motion module
# Using scheduler "k_dpmpp_sde" (DPMSolverSinglestepScheduler)
# Loading weights from /content/animatediff-cli-prompt-travel/data/models/sd/xxmix9realistic_v40.safetensors
# ^C

# %% [markdown]
# ## important. N.B.
# ## Note: the free tier may only have 12GB RAM which may cause the process to fail. Continue running following cell.
# ## Can experiment to disable the Controlnet or IPadaptor. (delete the images in the Controlnet or IPadaptor folders)
# ## Locations are: data\controlnet_image\test and data\ip_adapter_image\test. See video tutorial for details if you have any questions.
# ## Good luck!

# %%
# delete the images from the folder so it can run
os.remove("data/controlnet_image/test/controlnet_softedge/0000.png")
os.remove("data/controlnet_image/test/controlnet_softedge/0016.png")
os.remove("data/controlnet_image/test/controlnet_softedge/0032.png")
os.remove("data/controlnet_image/test/controlnet_openpose/0000.png")
os.remove("data/controlnet_image/test/controlnet_openpose/0016.png")
os.remove("data/controlnet_image/test/controlnet_openpose/0032.png")

# %%
# take about 4-5 minutes. -W is width -H height. -L length.  can use -W 512 -H 768
# !animatediff generate -c config/prompts/test001.json -W 256 -H 384 -L 128 -C 16
# Out:
# 2023-10-06 16:55:53.792172: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using generation config: config/prompts/test001.json
# is_v2=True
# Using base model: runwayml/stable-diffusion-v1-5
# Will save outputs to ./output/2023-10-06T16-56-08-tech-practice-xxmix9realistic_v40
# Checking motion module...
# Loading tokenizer...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading text encoder...
# Loading VAE...
# Loading UNet...
# Loaded 453.20928M-parameter motion module
# Using scheduler "k_dpmpp_sde" (DPMSolverSinglestepScheduler)
# Loading weights from /content/animatediff-cli-prompt-travel/data/models/sd/xxmix9realistic_v40.safetensors
# Downloading (…)lve/main/config.json: 100% 4.52k/4.52k [00:00<00:00, 21.6MB/s]
# Downloading (…)okenizer_config.json: 100% 905/905 [00:00<00:00, 4.61MB/s]
# Downloading (…)olve/main/vocab.json: 100% 961k/961k [00:00<00:00, 14.1MB/s]
# Downloading (…)olve/main/merges.txt: 100% 525k/525k [00:00<00:00, 23.4MB/s]
# Downloading (…)cial_tokens_map.json: 100% 389/389 [00:00<00:00, 2.70MB/s]
# Downloading (…)/main/tokenizer.json: 100% 2.22M/2.22M [00:00<00:00, 27.3MB/s]
# Merging weights into UNet...
# Creating AnimationPipeline...
# No TI embeddings found
# Sending pipeline to device "cuda"
# Selected data types: unet_dtype=torch.float16, tenc_dtype=torch.float16, vae_dtype=torch.float32
# Using channels_last memory format for UNet and VAE
# Saving prompt config to output directory
# Initialization complete!
# Generating 1 animations
# Running generation 1 of 1
# Generation seed: 5857359190905643317
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220/220  [ 0:03:57 < 0:00:00 , 1 it/s ]
# Generation complete, saving...
# Saving frames to 00-5857359190905643317   0% ━━━━━ 0/1… [ 0:00… < -:-… , ?     ]
# Saving frames to 00-5857359190905643317   0% ━━━━━ 0/1… [ 0:00… < -:-… , ?     ]
# Saving frames to 00-5857359190905643317   2% ━━━━━ 2/1… [ 0:00… < -:-… , ?     ]
# Saving frames to 00-5857359190905643317   4% ━━━━━ 5/1… [ 0:00… < 0:0… , 20    ]
# Saving frames to 00-5857359190905643317   5% ━━━━━ 7/1… [ 0:00… < 0:0… , 19    ]
# Saving frames to 00-5857359190905643317   5% ━━━━━ 7/1… [ 0:00… < 0:0… , 19    ]
# Saving frames to 00-5857359190905643317   8% ━━━━━ 10/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317   9% ━━━━━ 12/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  12% ╸━━━━ 15/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  12% ╸━━━━ 15/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  14% ╸━━━━ 18/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  16% ╸━━━━ 21/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  16% ╸━━━━ 21/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  19% ╸━━━━ 24/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  20% ━╺━━━ 26/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  22% ━╺━━━ 28/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  23% ━╺━━━ 30/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  25% ━╺━━━ 32/1… [ 0:0… < 0:00… , 19   ]
# Saving frames to 00-5857359190905643317  27% ━╺━━━ 34/1… [ 0:0… < 0:00… , 19   ]
# Saving frames to 00-5857359190905643317  28% ━╺━━━ 36/1… [ 0:0… < 0:00… , 19   ]
# Saving frames to 00-5857359190905643317  30% ━╺━━━ 38/1… [ 0:0… < 0:00… , 19   ]
# Saving frames to 00-5857359190905643317  32% ━╸━━━ 41/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  32% ━╸━━━ 41/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  34% ━╸━━━ 44/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  37% ━╸━━━ 47/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  39% ━╸━━━ 50/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  39% ━╸━━━ 50/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  41% ━━╺━━ 53/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  44% ━━╺━━ 56/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  46% ━━╺━━ 59/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  48% ━━╺━━ 62/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  48% ━━╺━━ 62/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  51% ━━╸━━ 65/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  53% ━━╸━━ 68/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  53% ━━╸━━ 68/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  55% ━━╸━━ 71/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  58% ━━╸━━ 74/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  58% ━━╸━━ 74/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  60% ━━━╺━ 77/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  62% ━━━╺━ 80/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  62% ━━━╺━ 80/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  65% ━━━╺━ 83/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  66% ━━━╺━ 85/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  68% ━━━╺━ 87/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  70% ━━━╺━ 89/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  71% ━━━╸━ 91/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  73% ━━━╸━ 93/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  74% ━━━╸━ 95/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  76% ━━━╸━ 97/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  77% ━━━╸━ 99/1… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  79% ━━━╸━ 101/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  81% ━━━━╺ 104/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  83% ━━━━╺ 106/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  84% ━━━━╺ 108/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  84% ━━━━╺ 108/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  87% ━━━━╺ 111/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  88% ━━━━╺ 113/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  91% ━━━━╸ 116/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  93% ━━━━╸ 119/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  93% ━━━━╸ 119/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  95% ━━━━╸ 122/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  98% ━━━━╸ 125/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  99% ━━━━╸ 127/… [ 0:0… < 0:00… , 20   ]
# Saving frames to 00-5857359190905643317  99% ━━━━╸ 127/… [ 0:0… < 0:00… , 20   ]
#                                                                           it/s
# Saved sample to output/2023-10-06T16-56-08-tech-practice-xxmix9realistic_v40/00_5857359190905643317_1girl_wizard_circlet_earrings_jewelry_purple-hair
# Generation complete!
# Done, exiting...

# %%
# Copy generated contents to Google drive
output_dir = "output"
gc.collect()

def get_new_dir(parent_dir):
  sub_dirs = []
  for path in os.listdir(parent_dir):
    dir_path = os.path.join(parent_dir, path)
    if os.path.isdir(dir_path):
      sub_dirs.append(dir_path)
  return max(sub_dirs, key = os.path.getmtime)

result_dir = get_new_dir(output_dir)
dest_dir = os.path.join(gd_output_dir, os.path.basename(result_dir))
shutil.copytree(result_dir, dest_dir, dirs_exist_ok = True)
print(f"🎉 The output files have been copied into {dest_dir}. (in your connected Google Drive) See you there! 🎉")
# Out:
# 🎉 The output files have been copied into GoogleDrive/MyDrive/AnimateDiffPromptTravel/output/2023-10-06T16-56-08-tech-practice-xxmix9realistic_v40. (in your connected Google Drive) See you there! 🎉

# %%
## The END

# %% [markdown]
# Good Luck. If you want to run it locally (needs a Nvidia or AMD GPU), I also video tutorial for them. Subscribe to it today! [Click to subscribe](https://www.youtube.com/@tech-practice9805?sub_confirmation=1)
